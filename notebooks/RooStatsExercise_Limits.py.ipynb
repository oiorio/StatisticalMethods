# %%
import ROOT
import sys
# Out:
# Welcome to JupyROOT 6.26/00

# %% [markdown]
# ## Let's load the previously generated file

# %%
fin = ROOT.TFile("WorkspaceFile.root")
ws = fin.Get("ws")
ws.Print()
# Out:
# RooWorkspace(ws) ws contents
#
# variables
# ---------
# (background,lam,mass,signal)
#
# p.d.f.s
# -------
# RooExponential::expo[ x=mass c=lam ] = 0.986073
# RooHistPdf::sighisto[ pdfObs=(mass) ] = 0
# RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.786755
#
# datasets
# --------
# RooDataSet::extPDFData(mass)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::dh(mass)

# %%
SBModel=ROOT.RooStats.ModelConfig()
SBModel.SetWorkspace(ws)
SBModel.SetPdf("sumPDF")
SBModel.SetName("SBModel")


poi = ROOT.RooArgSet(ws.var("signal"))#setting the parameter of interest

SBModel.SetParametersOfInterest(poi)
    
#for CLs (bounded intervals) use one-sided profile likelihood
profll = ROOT.RooStats.ProfileLikelihoodTestStat(SBModel.GetPdf())
profll.SetOneSided(1)
observables=ROOT.RooArgSet((ws.var("mass")))#we need to define the observable for the fit
SBModel.SetObservables(observables)
SBModel.Print()
    
BModel=SBModel.Clone("BOnlyModel")
BModel.SetParametersOfInterest(poi)
poi.find("signal").setVal(0.01)
BModel.SetSnapshot(poi) 
BModel.SetObservables(observables)
BModel.Print()
# Out:
# === Using the following for SBModel ===
# Observables:             RooArgSet:: = (mass)
# Parameters of Interest:  RooArgSet:: = (signal)
# PDF:                     RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.786755
#
#
# === Using the following for BOnlyModel ===
# Observables:             RooArgSet:: = (mass)
# Parameters of Interest:  RooArgSet:: = (signal)
# PDF:                     RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.986063
# Snapshot:
#   1) 0x556144de9640 RooRealVar:: signal = 0.01 +/- 24.3435  L(0 - 2000)  "signal events"

# %%
#define the dataset to test:
AllData=(ws.data("extPDFData")) #Full dataset
AllData.Print()
ROOT.RooStats.AsymptoticCalculator.SetPrintLevel(2)
# Out:
# RooDataSet::extPDFData[mass] = 1250 entries

# %%
def printLimits(DATA,SM,BM,poiname,paramsscan=None,valuepoi=None,signif=False,asymp=False,freq=False,postfix=""):
    BM.Print()
    SM.Print()
    if ( paramsscan is None):
        paramsscan ={"npoints":8,"poimin":0,"poimax":2000,"minplot":-1,"maxplot":-1}

    npoints=paramsscan["npoints"]
    poimin=paramsscan["poimin"]
    poimax=paramsscan["poimax"]
    minplot=paramsscan["minplot"]
    maxplot=paramsscan["maxplot"]
 
    ac= ROOT.RooStats.AsymptoticCalculator(DATA, BM, SM);
    ac.Initialize()

    fc= ROOT.RooStats.FrequentistCalculator(DATA, BM, SM);
    fc.SetToys(2500,500)


    if(signif):
        ahypo= ac.GetHypoTest()
        ahypo.Print()

    if(freq):
            
        #use frequentist approach: 
        #Warning: this will take a lot of time! 
        #In general: better use asymptotic approximation if number of events is rather large. 
        #Bias in the test statistic negative log likelihood, i.e. q0, will go as 1/sqrt(N) --> negligible for large datasets

        #Create hypotest inverter passing the calculator 
        freqCalc = ROOT.RooStats.HypoTestInverter(fc)

        #set confidence level (e.g. 90% upper limits)
        freqCalc.SetConfidenceLevel(0.90)

        #use CLs
        freqCalc.UseCLs(1)
 
        #Configure ToyMC Sampler
        toymcs = freqCalc.GetHypoTestCalculator().GetTestStatSampler()

        #choose the test statistics: profile NLL
        profll = ROOT.RooStats.ProfileLikelihoodTestStat(SM.GetPdf())

        #for CLs (bounded intervals) use one-sided profile likelihood
        profll.SetOneSided(1)

        #set the test statistic to use for toys
        toymcs.SetTestStatistic(profll)

          
        #generate pseudoexperiments to get the distribution of the test statistic
            
        freqCalc.SetFixedScan(npoints,poimin,poimax);
            
        result = freqCalc.GetInterval() #This is a HypoTestInveter class object
        result.Print()
        upperLimit = result.UpperLimit()
        exp=result.GetExpectedUpperLimit(0)
        p1=result.GetExpectedUpperLimit(1)
        m1=result.GetExpectedUpperLimit(-1)
        
        print ("====\n upper limit is ", upperLimit," exp ", exp, " p1 ",p1, " m1 ",m1, "\n\n ====")
        result.Print()
        c1=ROOT.TCanvas("limitCanvas") 
        c1.SetLogy()
        inv_plot = ROOT.RooStats.HypoTestInverterPlot("HTI_Result_Plot","result plot",result)
        if minplot!=-1 and maxplot!=-1:
            gr1 = inv_plot.MakePlot();
            gr1.Draw("ALP")
            gr1.GetYaxis().SetRangeUser(minplot,maxplot)
            gr2 = inv_plot.MakeExpectedPlot();
            gr2.Draw("LF")
            gr1.Draw("LP")

        inv_plot.Draw("2CL")
        c1.SaveAs("limitex"+postfix+".png")
            
    if(asymp):
        asympCalc = ROOT.RooStats.HypoTestInverter(ac)
        asympCalc.SetConfidenceLevel(0.90)
        #use CLs
        asympCalc.UseCLs(1)
        asympCalc.SetVerbose(3)

            
        asympCalc.SetFixedScan(npoints,poimin,poimax);
            
 
        result = asympCalc.GetInterval() #This is a HypoTestInveter class object
        result = asympCalc.GetInterval() #This is a HypoTestInveter class object
        result.Print()
        upperLimit = result.UpperLimit()
        exp=result.GetExpectedUpperLimit(0)
        p1=result.GetExpectedUpperLimit(1)
        m1=result.GetExpectedUpperLimit(-1)
        
        print ("====\n upper limit is ", upperLimit," exp ", exp, " p1 ",p1, " m1 ",m1, "\n\n ====")
        result.Print()
        c1=ROOT.TCanvas("limitCanvas") 
        c1.SetLogy()
        inv_plot = ROOT.RooStats.HypoTestInverterPlot("HTI_Result_Plot","result plot",result)
        if minplot!=-1 and maxplot!=-1:
            gr1 = inv_plot.MakePlot();
            gr1.Draw("ALP")
            gr1.GetYaxis().SetRangeUser(minplot,maxplot)
            gr2 = inv_plot.MakeExpectedPlot();
            gr2.Draw("LF")
            gr1.Draw("LP")

            inv_plot.Draw("2CL")
        else:
            inv_plot.Draw("2CL")
        c1.SaveAs("limitex"+postfix+".png")

# %%
doFreq=False
paramsscan_alt ={"npoints":20,"poimin":0,"poimax":500,"minplot":0.001,"maxplot":10}
paramsscan_all ={"npoints":20,"poimin":100,"poimax":600,"minplot":0.001,"maxplot":10}
if doFreq:
    paramsscan_alt ={"npoints":8,"poimin":0,"poimax":500,"minplot":0.001,"maxplot":10}
    paramsscan_all ={"npoints":8,"poimin":100,"poimax":600,"minplot":0.001,"maxplot":10}

# %%
doHypothesisTest=True
doAsymp=True
if(doHypothesisTest):
    poi.find("signal").setVal(250)
    SBModel.SetSnapshot(poi)
    
printLimits(DATA=AllData,BM=BModel,SM=SBModel,poiname="signal",signif=doHypothesisTest,asymp=doAsymp,paramsscan=paramsscan_all,postfix="all")
# Out:
# ====
#  upper limit is  298.96993565016766  exp  0.0  p1  0.0  m1  0.0
#
#  ====
#
# === Using the following for BOnlyModel ===
# Observables:             RooArgSet:: = (mass)
# Parameters of Interest:  RooArgSet:: = (signal)
# PDF:                     RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.788437
# Snapshot:
#   1) 0x5561451518e0 RooRealVar:: signal = 0.01 +/- 24.3435  L(0 - 2000)  "signal events"
#
#
# === Using the following for SBModel ===
# Observables:             RooArgSet:: = (mass)
# Parameters of Interest:  RooArgSet:: = (signal)
# PDF:                     RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.788437
# Snapshot:
#   1) 0x55613ca9a740 RooRealVar:: signal = 250 +/- 24.3435  L(0 - 2000)  "signal events"
#
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize....
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize - Find  best unconditional NLL on observed data
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm: caching constraint set under name CACHE_CONSTR_OF_PDF_sumPDF_FOR_OBS_mass with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   9.97334e+02  3.65636e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.02996e-02  4.48885e-04   -5.00000e+00  0.00000e+00
#      3 signal       2.50000e+02  2.43435e+01    0.00000e+00  2.00000e+03
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        1500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-409.803 FROM MIGRAD    STATUS=INITIATE        6 CALLS           7 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97334e+02   3.65636e+01   3.65718e-02  -1.04473e+00
#    2  lam         -1.02996e-02   4.48885e-04   1.98057e-03  -3.36248e+01
#    3  signal       2.50000e+02   2.43435e+01   3.68444e-02  -4.29594e+00
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-409.812 FROM MIGRAD    STATUS=CONVERGED      45 CALLS          46 TOTAL
#                      EDM=1.60659e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97332e+02   3.65591e+01   4.65153e-04  -1.12305e-02
#    2  lam         -1.02998e-02   4.48812e-04   2.34911e-05   9.29438e-02
#    3  signal       2.52657e+02   2.43377e+01   4.26785e-04   1.38941e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  3    ERR DEF=0.5
#   1.337e+03  5.529e-03 -3.398e+02
#   5.529e-03  2.014e-07 -5.530e-03
#  -3.398e+02 -5.530e-03  5.926e+02
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3
#         1  0.41654   1.000  0.337 -0.382
#         2  0.52948   0.337  1.000 -0.506
#         3  0.55363  -0.382 -0.506  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -409.812	fit time : Real time 0:00:00, CP time 1.120
# [#0] PROGRESS:Eval -- Best fitted POI value = 252.657 +/- 24.3377
# [#0] PROGRESS:Eval -- AsymptoticCalculator: Building Asimov data Set
# [#1] INFO:InputArguments -- AsymptoticCalculator: Asimov data will be generated using fitted nuisance parameter values
# MakeAsimov: Setting poi signal to a constant value = 0.01
# MakeAsimov: doing a conditional fit for finding best nuisance values
# POI values:
#   1) 0x5561440b6fa0 RooRealVar:: signal = 0.01 +/- 24.3435 C  L(0 - 2000)  "signal events"
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   9.97332e+02  3.65591e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.02998e-02  4.48812e-04   -5.00000e+00  0.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-255.003 FROM MIGRAD    STATUS=INITIATE        6 CALLS           7 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97332e+02   3.65591e+01   3.65674e-02  -2.53313e+02
#    2  lam         -1.02998e-02   4.48812e-04   1.98023e-03  -9.02262e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-340.385 FROM MIGRAD    STATUS=CONVERGED      32 CALLS          33 TOTAL
#                      EDM=7.92479e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.24968e+03   3.53375e+01   4.63099e-04  -2.33495e-01
#    2  lam         -7.73236e-03   2.21630e-04   1.43921e-05  -2.27868e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.249e+03  1.023e-07
#   1.023e-07  4.912e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00001   1.000  0.000
#         2  0.00001   0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# fit time Real time 0:00:00, CP time 0.120
#  Generate Asimov data for observables
# Generating Asimov data for pdf sumPDF
# list of observables
# RooArgList::dependents = (mass)
# looping on observable mass
# bin 0	  5 w = 93.0061
# bin 1	  15 w = 86.0856
# bin 2	  25 w = 79.68
# bin 3	  35 w = 73.751
# bin 4	  45 w = 68.2632
# bin 5	  55 w = 63.1838
# bin 6	  65 w = 58.4823
# bin 7	  75 w = 54.1306
# bin 8	  85 w = 50.1028
# bin 9	  95 w = 46.3747
# bin 10	  105 w = 42.9239
# bin 11	  115 w = 39.73
# bin 12	  125 w = 36.7737
# bin 13	  135 w = 34.0374
# bin 14	  145 w = 31.5048
# bin 15	  155 w = 29.1605
# bin 16	  165 w = 26.9908
# bin 17	  175 w = 24.9824
# bin 18	  185 w = 23.1237
# bin 19	  195 w = 21.4031
# bin 20	  205 w = 19.8107
# bin 21	  215 w = 18.3366
# bin 22	  225 w = 16.9724
# bin 23	  235 w = 15.7095
# bin 24	  245 w = 14.5408
# bin 25	  255 w = 13.4589
# bin 26	  265 w = 12.4574
# bin 27	  275 w = 11.5305
# bin 28	  285 w = 10.6723
# bin 29	  295 w = 9.87826
# bin 30	  305 w = 9.14306
# bin 31	  315 w = 8.46275
# bin 32	  325 w = 7.83294
# bin 33	  335 w = 7.25011
# bin 34	  345 w = 6.71055
# bin 35	  355 w = 6.21123
# bin 36	  365 w = 5.74899
# bin 37	  375 w = 5.32122
# bin 38	  385 w = 4.92524
# bin 39	  395 w = 4.55876
# bin 40	  405 w = 4.21952
# bin 41	  415 w = 3.90555
# bin 42	  425 w = 3.61494
# bin 43	  435 w = 3.34595
# bin 44	  445 w = 3.09698
# bin 45	  455 w = 2.86654
# bin 46	  465 w = 2.65323
# bin 47	  475 w = 2.45581
# bin 48	  485 w = 2.27307
# bin 49	  495 w = 2.10393
# bin 50	  505 w = 1.94738
# bin 51	  515 w = 1.80248
# bin 52	  525 w = 1.66835
# bin 53	  535 w = 1.54421
# bin 54	  545 w = 1.42931
# bin 55	  555 w = 1.32295
# bin 56	  565 w = 1.22451
# bin 57	  575 w = 1.1334
# bin 58	  585 w = 1.04906
# bin 59	  595 w = 0.971002
# bin 60	  605 w = 0.89875
# bin 61	  615 w = 0.831874
# bin 62	  625 w = 0.769974
# bin 63	  635 w = 0.712681
# bin 64	  645 w = 0.65965
# bin 65	  655 w = 0.610566
# bin 66	  665 w = 0.565134
# bin 67	  675 w = 0.523082
# bin 68	  685 w = 0.48416
# bin 69	  695 w = 0.448134
# bin 70	  705 w = 0.414788
# bin 71	  715 w = 0.383924
# bin 72	  725 w = 0.355356
# bin 73	  735 w = 0.328914
# bin 74	  745 w = 0.30444
# bin 75	  755 w = 0.281787
# bin 76	  765 w = 0.260819
# bin 77	  775 w = 0.241412
# bin 78	  785 w = 0.223448
# bin 79	  795 w = 0.206821
# bin 80	  805 w = 0.191432
# bin 81	  815 w = 0.177188
# bin 82	  825 w = 0.164003
# bin 83	  835 w = 0.1518
# bin 84	  845 w = 0.140504
# bin 85	  855 w = 0.130049
# bin 86	  865 w = 0.120372
# bin 87	  875 w = 0.111416
# bin 88	  885 w = 0.103125
# bin 89	  895 w = 0.0954517
# bin 90	  905 w = 0.0883491
# bin 91	  915 w = 0.0817751
# bin 92	  925 w = 0.0756902
# bin 93	  935 w = 0.0700581
# bin 94	  945 w = 0.0648451
# bin 95	  955 w = 0.06002
# bin 96	  965 w = 0.055554
# bin 97	  975 w = 0.0514202
# bin 98	  985 w = 0.047594
# bin 99	  995 w = 0.0440526
# ending loop on .. mass
# filled from sumPDF   100 nbins  volume is 1
# RooDataSet::AsimovData[mass,weight:binWeightAsimov] = 100 entries (1249.38 weighted)
# Generated Asimov data for observables RooArgSet:: = (mass)
# --- Asimov data numEntries = 100 sumOfEntries = 1249.38
# 	time for generating : Real time 0:00:00, CP time 0.010
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize Find  best conditional NLL on ASIMOV data set for given alt POI ( signal ) = 0.01
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **    7 **SET PRINT           1
#  **********
#  **********
#  **    8 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   1.24968e+03  3.53375e+01    0.00000e+00  2.00000e+03
#      2 lam         -7.73236e-03  2.21630e-04   -5.00000e+00  0.00000e+00
#  **********
#  **    9 **SET ERR         0.5
#  **********
#  **********
#  **   10 **SET PRINT           1
#  **********
#  **********
#  **   11 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   12 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-339.065 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.24968e+03   3.53375e+01   3.65031e-02   2.41127e-01
#    2  lam         -7.73236e-03   2.21630e-04   1.12815e-03  -1.58153e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-339.066 FROM MIGRAD    STATUS=CONVERGED      23 CALLS          24 TOTAL
#                      EDM=3.21403e-12    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.24937e+03   3.53387e+01   4.64620e-04  -3.11977e-05
#    2  lam         -7.72841e-03   2.21583e-04   1.43558e-05   1.22748e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.249e+03  5.950e-08
#   5.950e-08  4.910e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00001   1.000  0.000
#         2  0.00001   0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -339.066 for poi fixed at = 0.01	fit time : Real time 0:00:00, CP time 0.010
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize....
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize - Find  best unconditional NLL on observed data
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   1.24937e+03  3.53387e+01    0.00000e+00  2.00000e+03
#      2 lam         -7.72841e-03  2.21583e-04   -5.00000e+00  0.00000e+00
#      3 signal       1.00000e-02  2.43435e+01    0.00000e+00  2.00000e+03
#  MINUIT WARNING IN PARAMETR
#  ============== VARIABLE3 BROUGHT BACK INSIDE LIMITS.
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        1500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-376.171 FROM MIGRAD    STATUS=INITIATE       21 CALLS          22 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.24937e+03   3.53387e+01   0.00000e+00   1.02589e+02
#    2  lam         -7.72841e-03   2.21583e-04   0.00000e+00   3.28919e+03
#    3  signal       1.29295e+02   2.43435e+01   5.09691e-01  -1.40228e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-409.812 FROM MIGRAD    STATUS=CONVERGED      77 CALLS          78 TOTAL
#                      EDM=2.78348e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97338e+02   3.65593e+01   4.64987e-04  -1.02252e-02
#    2  lam         -1.02997e-02   4.48800e-04   2.34974e-05   2.63843e-01
#    3  signal       2.52652e+02   2.43376e+01   4.26745e-04   3.17224e-04
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  3    ERR DEF=0.5
#   1.337e+03  5.529e-03 -3.398e+02
#   5.529e-03  2.014e-07 -5.530e-03
#  -3.398e+02 -5.530e-03  5.926e+02
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3
#         1  0.41654   1.000  0.337 -0.382
#         2  0.52947   0.337  1.000 -0.506
#         3  0.55363  -0.382 -0.506  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -409.812	fit time : Real time 0:00:00, CP time 0.050
# [#0] PROGRESS:Eval -- Best fitted POI value = 252.652 +/- 24.3376
# [#0] PROGRESS:Eval -- AsymptoticCalculator: Building Asimov data Set
# [#1] INFO:InputArguments -- AsymptoticCalculator: Asimov data will be generated using fitted nuisance parameter values
# MakeAsimov: Setting poi signal to a constant value = 0.01
# MakeAsimov: doing a conditional fit for finding best nuisance values
# POI values:
#   1) 0x5561440b6fa0 RooRealVar:: signal = 0.01 +/- 24.3435 C  L(0 - 2000)  "signal events"
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   9.97338e+02  3.65593e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.02997e-02  4.48800e-04   -5.00000e+00  0.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-255.011 FROM MIGRAD    STATUS=INITIATE        6 CALLS           7 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97338e+02   3.65593e+01   3.65676e-02  -2.53306e+02
#    2  lam         -1.02997e-02   4.48800e-04   1.98019e-03  -9.02210e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-340.385 FROM MIGRAD    STATUS=CONVERGED      32 CALLS          33 TOTAL
#                      EDM=7.91891e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.24968e+03   3.53376e+01   4.63099e-04  -2.33416e-01
#    2  lam         -7.73236e-03   2.21630e-04   1.43921e-05  -2.27704e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.249e+03  1.023e-07
#   1.023e-07  4.912e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00001   1.000  0.000
#         2  0.00001   0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# fit time Real time 0:00:00, CP time 0.000
#  Generate Asimov data for observables
# Generating Asimov data for pdf sumPDF
# list of observables
# RooArgList::dependents = (mass)
# looping on observable mass
# bin 0	  5 w = 93.0061
# bin 1	  15 w = 86.0856
# bin 2	  25 w = 79.68
# bin 3	  35 w = 73.751
# bin 4	  45 w = 68.2632
# bin 5	  55 w = 63.1838
# bin 6	  65 w = 58.4823
# bin 7	  75 w = 54.1306
# bin 8	  85 w = 50.1028
# bin 9	  95 w = 46.3747
# bin 10	  105 w = 42.9239
# bin 11	  115 w = 39.73
# bin 12	  125 w = 36.7737
# bin 13	  135 w = 34.0374
# bin 14	  145 w = 31.5048
# bin 15	  155 w = 29.1605
# bin 16	  165 w = 26.9908
# bin 17	  175 w = 24.9824
# bin 18	  185 w = 23.1237
# bin 19	  195 w = 21.4031
# bin 20	  205 w = 19.8107
# bin 21	  215 w = 18.3366
# bin 22	  225 w = 16.9724
# bin 23	  235 w = 15.7095
# bin 24	  245 w = 14.5408
# bin 25	  255 w = 13.4589
# bin 26	  265 w = 12.4574
# bin 27	  275 w = 11.5305
# bin 28	  285 w = 10.6723
# bin 29	  295 w = 9.87826
# bin 30	  305 w = 9.14306
# bin 31	  315 w = 8.46275
# bin 32	  325 w = 7.83295
# bin 33	  335 w = 7.25011
# bin 34	  345 w = 6.71055
# bin 35	  355 w = 6.21123
# bin 36	  365 w = 5.74899
# bin 37	  375 w = 5.32122
# bin 38	  385 w = 4.92524
# bin 39	  395 w = 4.55876
# bin 40	  405 w = 4.21952
# bin 41	  415 w = 3.90555
# bin 42	  425 w = 3.61494
# bin 43	  435 w = 3.34595
# bin 44	  445 w = 3.09698
# bin 45	  455 w = 2.86654
# bin 46	  465 w = 2.65324
# bin 47	  475 w = 2.45581
# bin 48	  485 w = 2.27307
# bin 49	  495 w = 2.10393
# bin 50	  505 w = 1.94738
# bin 51	  515 w = 1.80248
# bin 52	  525 w = 1.66836
# bin 53	  535 w = 1.54421
# bin 54	  545 w = 1.42931
# bin 55	  555 w = 1.32295
# bin 56	  565 w = 1.22451
# bin 57	  575 w = 1.1334
# bin 58	  585 w = 1.04906
# bin 59	  595 w = 0.971002
# bin 60	  605 w = 0.89875
# bin 61	  615 w = 0.831874
# bin 62	  625 w = 0.769975
# bin 63	  635 w = 0.712681
# bin 64	  645 w = 0.659651
# bin 65	  655 w = 0.610566
# bin 66	  665 w = 0.565134
# bin 67	  675 w = 0.523083
# bin 68	  685 w = 0.48416
# bin 69	  695 w = 0.448134
# bin 70	  705 w = 0.414788
# bin 71	  715 w = 0.383924
# bin 72	  725 w = 0.355356
# bin 73	  735 w = 0.328915
# bin 74	  745 w = 0.30444
# bin 75	  755 w = 0.281787
# bin 76	  765 w = 0.260819
# bin 77	  775 w = 0.241412
# bin 78	  785 w = 0.223448
# bin 79	  795 w = 0.206822
# bin 80	  805 w = 0.191432
# bin 81	  815 w = 0.177188
# bin 82	  825 w = 0.164003
# bin 83	  835 w = 0.1518
# bin 84	  845 w = 0.140504
# bin 85	  855 w = 0.130049
# bin 86	  865 w = 0.120372
# bin 87	  875 w = 0.111416
# bin 88	  885 w = 0.103125
# bin 89	  895 w = 0.0954517
# bin 90	  905 w = 0.0883492
# bin 91	  915 w = 0.0817751
# bin 92	  925 w = 0.0756903
# bin 93	  935 w = 0.0700582
# bin 94	  945 w = 0.0648452
# bin 95	  955 w = 0.0600201
# bin 96	  965 w = 0.055554
# bin 97	  975 w = 0.0514202
# bin 98	  985 w = 0.0475941
# bin 99	  995 w = 0.0440526
# ending loop on .. mass
# filled from sumPDF   100 nbins  volume is 1
# RooDataSet::AsimovData[mass,weight:binWeightAsimov] = 100 entries (1249.38 weighted)
# Generated Asimov data for observables RooArgSet:: = (mass)
# --- Asimov data numEntries = 100 sumOfEntries = 1249.38
# 	time for generating : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize Find  best conditional NLL on ASIMOV data set for given alt POI ( signal ) = 0.01
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **    7 **SET PRINT           1
#  **********
#  **********
#  **    8 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   1.24968e+03  3.53376e+01    0.00000e+00  2.00000e+03
#      2 lam         -7.73236e-03  2.21630e-04   -5.00000e+00  0.00000e+00
#  **********
#  **    9 **SET ERR         0.5
#  **********
#  **********
#  **   10 **SET PRINT           1
#  **********
#  **********
#  **   11 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   12 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-339.065 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.24968e+03   3.53376e+01   3.65031e-02   2.41127e-01
#    2  lam         -7.73236e-03   2.21630e-04   1.12815e-03  -1.58153e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-339.066 FROM MIGRAD    STATUS=CONVERGED      23 CALLS          24 TOTAL
#                      EDM=3.21402e-12    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.24937e+03   3.53387e+01   4.64620e-04  -3.11977e-05
#    2  lam         -7.72841e-03   2.21583e-04   1.43558e-05   1.22748e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.249e+03  5.950e-08
#   5.950e-08  4.910e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00001   1.000  0.000
#         2  0.00001   0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -339.066 for poi fixed at = 0.01	fit time : Real time 0:00:00, CP time 0.000
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( signal ) = 250
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   13 **SET PRINT           1
#  **********
#  **********
#  **   14 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   9.97338e+02  3.65593e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.02997e-02  4.48800e-04   -5.00000e+00  0.00000e+00
#  **********
#  **   15 **SET ERR         0.5
#  **********
#  **********
#  **   16 **SET PRINT           1
#  **********
#  **********
#  **   17 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   18 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-409.803 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97338e+02   3.65593e+01   3.65676e-02  -1.04041e+00
#    2  lam         -1.02997e-02   4.48800e-04   1.98019e-03  -3.37577e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-409.806 FROM MIGRAD    STATUS=CONVERGED      20 CALLS          21 TOTAL
#                      EDM=3.79838e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.98705e+02   3.38076e+01   4.64759e-04  -1.69116e-01
#    2  lam         -1.02740e-02   3.85355e-04   2.34706e-05   2.08243e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.143e+03  2.340e-03
#   2.340e-03  1.485e-07
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.17957   1.000  0.180
#         2  0.17957   0.180  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -409.806 for poi fixed at = 250	fit time : Real time 0:00:00, CP time 0.010
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.0119519 condNLL = -409.806 uncond -409.812
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   19 **SET PRINT           1
#  **********
#  **********
#  **   20 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   9.98705e+02  3.38076e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.02740e-02  3.85355e-04   -5.00000e+00  0.00000e+00
#  **********
#  **   21 **SET ERR         0.5
#  **********
#  **********
#  **   22 **SET PRINT           1
#  **********
#  **********
#  **   23 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   24 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-265.694 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.98705e+02   3.38076e+01   3.38140e-02  -7.92787e+01
#    2  lam         -1.02740e-02   3.85355e-04   1.70227e-03  -3.12497e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-280.303 FROM MIGRAD    STATUS=CONVERGED      29 CALLS          30 TOTAL
#                      EDM=4.08316e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.09977e+03   3.44877e+01   3.99268e-04  -1.02075e-02
#    2  lam         -8.82908e-03   2.84568e-04   1.56380e-05   1.48935e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.190e+03  8.122e-04
#   8.122e-04  8.098e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.08274   1.000  0.083
#         2  0.08274   0.083  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -280.303 for poi fixed at = 250	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 117.526 condNLL = -280.303 uncond -339.066
# [#1] INFO:InputArguments -- Minimum of POI is 0 is different to alt snapshot 0.01 - using standard q asymptotic formulae
# [#0] PROGRESS:Eval -- poi = 250 qmu = 0.0119519 qmu_A = 117.526 sigma = 23.0607  CLsplusb = 0.912945 CLb = 1 CLs = 1.09536
#
# Results HypoTestAsymptotic_result:
#  - Null p-value = 0.912945
#  - Significance = -1.35912
#  - CL_b: 0.912945
#  - CL_s+b: 1
#  - CL_s: 1.09536
# [#1] INFO:InputArguments -- HypoTestInverter ---- Input models:
# 		 using as S+B (null) model     : SBModel
# 		 using as B (alternate) model  : BOnlyModel
#
# [#0] WARNING:InputArguments -- HypoTestInverter - using a B model  with POI signal not equal to zero  user must check input model configurations
# [#1] INFO:Eval -- HypoTestInverter::GetInterval - run a fixed scan
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(ws) replacing previous snapshot with name SBModel__snapshot
# [#0] PROGRESS:Eval -- Running for signal = 100
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( signal ) = 100
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   25 **SET PRINT           1
#  **********
#  **********
#  **   26 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   9.97338e+02  3.65593e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.02997e-02  4.48800e-04   -5.00000e+00  0.00000e+00
#  **********
#  **   27 **SET ERR         0.5
#  **********
#  **********
#  **   28 **SET PRINT           1
#  **********
#  **********
#  **   29 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   30 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-370.336 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97338e+02   3.65593e+01   3.65676e-02  -9.02842e+01
#    2  lam         -1.02997e-02   4.48800e-04   1.98019e-03  -3.09037e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-387.022 FROM MIGRAD    STATUS=CONVERGED      31 CALLS          32 TOTAL
#                      EDM=8.38318e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.11773e+03   3.49742e+01   4.75727e-04  -6.59191e-02
#    2  lam         -8.77181e-03   2.84737e-04   1.84103e-05   1.46207e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.224e+03  1.043e-03
#   1.043e-03  8.107e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.10470   1.000  0.105
#         2  0.10470   0.105  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -387.022 for poi fixed at = 100	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 45.5796 condNLL = -387.022 uncond -409.812
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   31 **SET PRINT           1
#  **********
#  **********
#  **   32 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   1.11773e+03  3.49742e+01    0.00000e+00  2.00000e+03
#      2 lam         -8.77181e-03  2.84737e-04   -5.00000e+00  0.00000e+00
#  **********
#  **   33 **SET ERR         0.5
#  **********
#  **********
#  **   34 **SET PRINT           1
#  **********
#  **********
#  **   35 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   36 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-324.604 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.11773e+03   3.49742e+01   3.52267e-02  -4.12298e+01
#    2  lam         -8.77181e-03   2.84737e-04   1.36098e-03  -1.53717e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-327.648 FROM MIGRAD    STATUS=CONVERGED      25 CALLS          26 TOTAL
#                      EDM=2.23789e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.17046e+03   3.50980e+01   4.43260e-04  -8.18259e-02
#    2  lam         -8.25215e-03   2.51648e-04   1.54780e-05  -2.88541e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.232e+03  4.580e-04
#   4.580e-04  6.333e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.05184   1.000  0.052
#         2  0.05184   0.052  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -327.648 for poi fixed at = 100	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 22.8346 condNLL = -327.648 uncond -339.066
# [#0] PROGRESS:Eval -- poi = 100 qmu = 45.5796 qmu_A = 22.8346 sigma = 20.9268  CLsplusb = 1.46561e-11 CLb = 0.0242643 CLs = 1.65557e+09
# [#0] PROGRESS:Eval -- P values for  signal =  100
# 	CLs      = 6.0402e-10 +/- 0
# 	CLb      = 0.0242643 +/- 0
# 	CLsplusb = 1.46561e-11 +/- 0
#
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(ws) replacing previous snapshot with name SBModel__snapshot
# [#0] PROGRESS:Eval -- Running for signal = 126.316
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( signal ) = 126.316
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   37 **SET PRINT           1
#  **********
#  **********
#  **   38 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   9.97338e+02  3.65593e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.02997e-02  4.48800e-04   -5.00000e+00  0.00000e+00
#  **********
#  **   39 **SET ERR         0.5
#  **********
#  **********
#  **   40 **SET PRINT           1
#  **********
#  **********
#  **   41 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   42 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-384.578 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.97338e+02   3.65593e+01   3.65676e-02  -6.81036e+01
#    2  lam         -1.02997e-02   4.48800e-04   1.98019e-03  -2.31331e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-394.614 FROM MIGRAD    STATUS=CONVERGED      31 CALLS          32 TOTAL
#                      EDM=1.85615e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.09139e+03   3.47993e+01   4.75545e-04   1.82888e-02
#    2  lam         -9.04568e-03   3.02571e-04   1.94102e-05   7.90995e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.211e+03  1.307e-03
#   1.307e-03  9.155e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.12414   1.000  0.124
#         2  0.12414   0.124  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -394.614 for poi fixed at = 126.316	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 30.395 condNLL = -394.614 uncond -409.812
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   43 **SET PRINT           1
#  **********
#  **********
#  **   44 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   1.09139e+03  3.47993e+01    0.00000e+00  2.00000e+03
#      2 lam         -9.04568e-03  3.02571e-04   -5.00000e+00  0.00000e+00
#  **********
#  **   45 **SET ERR         0.5
#  **********
#  **********
#  **   46 **SET PRINT           1
#  **********
#  **********
#  **   47 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   48 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-316.852 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.09139e+03   3.47993e+01   3.49528e-02  -4.97716e+01
#    2  lam         -9.04568e-03   3.02571e-04   1.42422e-03  -1.87571e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-321.514 FROM MIGRAD    STATUS=CONVERGED      34 CALLS          35 TOTAL
#                      EDM=4.78466e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.15510e+03   3.49987e+01   4.38209e-04  -5.45229e-04
#    2  lam         -8.36791e-03   2.58320e-04   1.56355e-05   9.08230e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.225e+03  5.419e-04
#   5.419e-04  6.673e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.05992   1.000  0.060
#         2  0.05992   0.060  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -321.514 for poi fixed at = 126.316	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 35.1035 condNLL = -321.514 uncond -339.066
# [#0] PROGRESS:Eval -- poi = 126.316 qmu = 30.395 qmu_A = 35.1035 sigma = 21.3198  CLsplusb = 3.52427e-08 CLb = 0.659703 CLs = 1.87189e+07
# [#0] PROGRESS:Eval -- P values for  signal =  126.316
# 	CLs      = 5.3422e-08 +/- 0
# 	CLb      = 0.659703 +/- 0
# 	CLsplusb = 3.52427e-08 +/- 0
#
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(ws) replacing previous snapshot with name SBModel__snapshot
# ...
#  FCN=-333.182 FROM MIGRAD    STATUS=CONVERGED      31 CALLS          32 TOTAL
#                      EDM=7.26904e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   8.81440e+02   3.15318e+01   3.94183e-04  -5.27973e-02
#    2  lam         -1.28137e-02   5.41708e-04   2.65173e-05   1.14257e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   9.946e+02  3.199e-03
#   3.199e-03  2.934e-07
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.18725   1.000  0.187
#         2  0.18725   0.187  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -333.182 for poi fixed at = 600	fit time : Real time 0:00:00, CP time 0.010
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 153.259 condNLL = -333.182 uncond -409.812
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- createConstraintTerm picked up cached constraints from workspace with 0 entries
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  259 **SET PRINT           1
#  **********
#  **********
#  **  260 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   8.81440e+02  3.15318e+01    0.00000e+00  2.00000e+03
#      2 lam         -1.28137e-02  5.41708e-04   -5.00000e+00  0.00000e+00
#  **********
#  **  261 **SET ERR         0.5
#  **********
#  **********
#  **  262 **SET PRINT           1
#  **********
#  **********
#  **  263 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **  264 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-57.7186 FROM MIGRAD    STATUS=INITIATE        8 CALLS           9 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   8.81440e+02   3.15318e+01   3.17613e-02  -1.05818e+02
#    2  lam         -1.28137e-02   5.41708e-04   2.14337e-03  -4.60717e+03
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-97.385 FROM MIGRAD    STATUS=CONVERGED      33 CALLS          34 TOTAL
#                      EDM=6.85936e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.01609e+03   3.33503e+01   2.25513e-04  -2.08733e-01
#    2  lam         -9.67842e-03   3.31688e-04   1.03057e-05  -2.54730e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   1.113e+03  1.100e-03
#   1.100e-03  1.100e-07
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.09941   1.000  0.099
#         2  0.09941   0.099  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# AsymptoticCalculator::EvaluateNLL -  value = -97.385 for poi fixed at = 600	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 483.361 condNLL = -97.385 uncond -339.066
# [#0] PROGRESS:Eval -- poi = 600 qmu = 153.259 qmu_A = 483.361 sigma = 27.2907  CLsplusb = 3.36301e-35 CLb = 1 CLs = 2.97353e+34
# [#0] PROGRESS:Eval -- P values for  signal =  600
# 	CLs      = 3.36301e-35 +/- 0
# 	CLb      = 1 +/- 0
# 	CLsplusb = 3.36301e-35 +/- 0
#
# [#1] INFO:Eval -- HypoTestInverter::GetInterval - return an already existing interval
# OBJ: RooStats::HypoTestInverterResult	result_signal	HypoTestInverter Result For signal
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# HypoTestInverterResult - set a minimum size of 10 for limit distribution
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# HypoTestInverterResult - set a minimum size of 10 for limit distribution
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# HypoTestInverterResult - set a minimum size of 10 for limit distribution
# OBJ: RooStats::HypoTestInverterResult	result_signal	HypoTestInverter Result For signal
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# [#0] ERROR:Eval -- Error finding expected p-values - return -1
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <ROOT::Math::BrentMethods::MinimStep>: Grid search failed to find a root in the  interval
# Info in <ROOT::Math::BrentMethods::MinimStep>: xmin = 0 xmax = 20 npts = 100
# Error in <ROOT::Math::BrentRootFinder>: Interval does not contain a root
# Info in <TCanvas::Print>: png file limitexall.png has been created

# %% [raw]
# fin.Close()
# fin = ROOT.TFile("WorkspaceFile.root")
# ws = fin.Get("ws")
# ws.Print()

# %%
SmallSigData=ws.pdf("sighisto").generate(ws.var("mass"),20)
SmallSigAllData=ws.pdf("expo").generate(ws.var("mass"),1000)
SmallSigAllData.append(SmallSigData)
SBModelSmallSig=ROOT.RooStats.ModelConfig()
SBModelSmallSig.SetWorkspace(ws)
SBModelSmallSig.SetParametersOfInterest(poi)
SBModelSmallSig.SetPdf(ws.pdf("sumPDF"))
BModelSmallSig=SBModelSmallSig.Clone("BModelSmallSig")
BModelSmallSig.SetParametersOfInterest(poi)
poi.find("signal").setVal(0.01)
BModelSmallSig.SetSnapshot(poi) 
BModelSmallSig.SetObservables(observables)
BModelSmallSig.Print()
# Out:
# === Using the following for BModelSmallSig ===
# Observables:             RooArgSet:: = (mass)
# Parameters of Interest:  RooArgSet:: = (signal)
# PDF:                     RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.0092217/1
# Snapshot:
#   1) 0x556146224aa0 RooRealVar:: signal = 0.01 +/- 24.3376  L(0 - 2000)  "signal events"
