# %%
import ROOT
import sys
# Out:
# Welcome to JupyROOT 6.26/00

# %% [markdown]
# ## Part 1: generation and basics

# %% [markdown]
# In this case, we want an example like this, i.e. an exponential background and a peaked (e.g. Gaussian) distribution:
# ![ZImpact_cms_22Dic-2.png](attachment:ZImpact_cms_22Dic-2.png)

# %% [markdown]
# 1.1 Fit variables: you define the random variables involved:
# - mass (x axis)
# - number of events n

# %%
mass = ROOT.RooRealVar("mass","mass plot",0,1000,"GeV")  
nsignal=250
nbackground=1000
nev = ROOT.RooRealVar("n","n events",nsignal+nbackground,0,2000)

# %% [markdown]
# 1.2 Parameters of the distribution:
# - number of signal events
# - number of background events
# - function parameters: mean, width of the gaussian, slope of the exponential (lambda)

# %%
signal = ROOT.RooRealVar("signal","signal events",nsignal,0,2000) 
background = ROOT.RooRealVar("background","signal events",nbackground,0,2000) 
    
mean = ROOT.RooRealVar("mean","signal mean",200,0,1000)
sigma = ROOT.RooRealVar("sigma","signal sigma",50,0,1000) 
mean2 = ROOT.RooRealVar("mean","signal mean",0,-1000,1000)
sigma2 = ROOT.RooRealVar("sigma","signal sigma",120,0,1000) 
lam = ROOT.RooRealVar("lam","lam",-0.01,-5,0)

#Computing total number of events as new "composite" variable
totevents = ROOT.RooFormulaVar("total_events", "signal+background", ROOT.RooArgList(signal,background))

# %% [markdown]
# We define two pdfs which are already included in the ROOT libraries

# %%
h1 = ROOT.TH1F("s","s",100,0,2000)
f1=ROOT.TF1("gaus","gaus",0,2000)
f1.SetParameters(1,250,50)
h1.FillRandom("gaus",2000)
c1=ROOT.TCanvas("c1")
h1.Draw()
c1.Draw()

# %%
dh = ROOT.RooDataHist("dh", "dh", ROOT.RooArgList(mass), Import=(h1))
SignalHistoShape= ROOT.RooHistPdf("sighisto","signal histo pdf",mass,dh)

# %%
BkgShape = ROOT.RooExponential("expo","Roofit Exponential function",mass,lam)#Background exponential pdf, 

SigShape = ROOT.RooGaussian("gauss","Roofit Gaussian function",mass, mean,sigma)#Signal gaussian pdf, already normalized
SigShape2 = ROOT.RooGaussian("gauss","Roofit Gaussian function",mass, mean2,sigma2)#Signal gaussian pdf, already normalized

TotalSigShape =ROOT.RooAddPdf("totalsig","Total signal considering two gaussians",ROOT.RooArgList(SigShape,SigShape2))
# Out:
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 1000] of the RooGaussian 'gauss' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 1000] of the RooGaussian 'gauss' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] ERROR:InputArguments -- RooAddPdf::RooAddPdf(totalsig) pdf gauss is not extendable, ignored
# [#0] ERROR:InputArguments -- RooAddPdf::RooAddPdf(totalsig) pdf gauss is not extendable, ignored

# %% [markdown]
# 1.2 Generation of MC events. We first generate a number of events:
#
# We take the *variable* (nev) and generate according to the *parameter* (s+b=totevents)

# %%
ExpEvents = ROOT.RooPoisson("pois","Total number of events",nev,totevents)

# %%
sum_pdf = ROOT.RooAddPdf("sumPDF","Total s+b PDF",ROOT.RooArgList(SignalHistoShape,BkgShape),ROOT.RooArgList(signal,background))
prod_sum_pdf = ROOT.RooProdPdf("extPDF","Total s+b PDF with nevents",ROOT.RooArgList(sum_pdf,ExpEvents))

# %%
total_events=prod_sum_pdf.generate(ROOT.RooArgSet(mass,nev))
BinnedEvents=total_events.binnedClone()#the equivalent but divided in bins
#BinnedEvents=total_events.binnedClone()#the equivalent but divided in bins

# %%
    
#Plotting routines: we make a canvas
c1=ROOT.TCanvas("c1","c1",50,50,1200,600)
# divided in two pieces
c1.Divide(2,1)
#First one
c1.cd(1)
#We create a plot from the first random variable
frame = mass.frame(ROOT.RooFit.Title("mass distribution"))
BinnedEvents.plotOn(frame)
frame.Draw()
#We create a plot from the second random variable
framenev = nev.frame(ROOT.RooFit.Title("number of events distribution"))
c1.cd(2)
BinnedEvents.Clone().plotOn(framenev)
framenev.Draw()
c1.Draw()
c1.SaveAs("exampleEvents.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: png file exampleEvents.png has been created

# %%
#Let's generate a mass distribution:
total_events=prod_sum_pdf.generate(ROOT.RooArgSet(mass))
BinnedEvents=total_events.binnedClone()#the equivalent but divided in bins

# %%
#And fit it:
prod_sum_pdf.fitTo(total_events, ROOT.RooFit.Extended(1))#pdf . fit to (dataset, options)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (pois)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (background,lam,signal)
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_extPDF_extPDFData_with_constr) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (sighisto)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (expo)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 background   1.00000e+03  2.00000e+02    0.00000e+00  2.00000e+03
#      2 lam         -1.00000e-02  5.00000e-03   -5.00000e+00  0.00000e+00
#      3 n            1.25000e+03  2.00000e+02    0.00000e+00  2.00000e+03
#      4 signal       2.50000e+02  1.25000e+02    0.00000e+00  2.00000e+03
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(pois_Int[background,signal]) using numeric integrator RooAdaptiveIntegratorND to calculate Int(signal,background)
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-397.923 FROM MIGRAD    STATUS=INITIATE       41 CALLS          42 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   1.00000e+03   2.00000e+02   0.00000e+00  -1.28079e+00
#    2  lam         -1.00000e-02   5.00000e-03   0.00000e+00   4.42443e+02
#    3  n            1.24893e+03   2.00000e+02  -1.10720e-03   5.92892e-08
#    4  signal       2.50000e+02   1.25000e+02   0.00000e+00   8.68002e+00
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-398.197 FROM MIGRAD    STATUS=CONVERGED     186 CALLS         187 TOTAL
#                      EDM=0.000843848    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  background   9.96150e+02   3.65225e+01   3.33731e-04   3.71619e-04
#    2  lam         -1.02998e-02   4.48814e-04   2.31569e-05  -4.58245e-03
#    3  n            1.24730e+03   5.35083e+01   2.21151e-03  -5.25736e-01
#    4  signal       2.52350e+02   2.43099e+01   3.64802e-04  -1.14007e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   1.334e+03  5.521e-03  1.067e+03 -3.386e+02
#   5.521e-03  2.014e-07 -3.860e-06 -5.523e-03
#   1.067e+03 -3.860e-06  2.866e+03  2.708e+02
#  -3.386e+02 -5.523e-03  2.708e+02  5.912e+02
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.74901   1.000  0.337  0.545 -0.381
#         2  0.52948   0.337  1.000 -0.000 -0.506
#         3  0.70707   0.545 -0.000  1.000  0.208
#         4  0.69127  -0.381 -0.506  0.208  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-398.197 FROM HESSE     STATUS=OK             29 CALLS         216 TOTAL
#                      EDM=0.000843916    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  background   9.96150e+02   3.65335e+01   1.33493e-05  -3.85048e-03
#    2  lam         -1.02998e-02   4.48918e-04   9.26275e-07   1.47999e+00
#    3  n            1.24730e+03   4.95024e+01   1.63659e-02   2.49888e-01
#    4  signal       2.52350e+02   2.43161e+01   7.29603e-05  -8.44516e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   1.335e+03  5.530e-03  9.872e+02 -3.392e+02
#   5.530e-03  2.015e-07 -1.846e-07 -5.530e-03
#   9.872e+02 -1.846e-07  2.453e+03  2.501e+02
#  -3.392e+02 -5.530e-03  2.501e+02  5.915e+02
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.74918   1.000  0.337  0.546 -0.382
#         2  0.52980   0.337  1.000 -0.000 -0.506
#         3  0.70710   0.546 -0.000  1.000  0.208
#         4  0.69146  -0.382 -0.506  0.208  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] WARNING:NumericIntegration -- RooAdaptiveIntegratorND::dtor(pois) WARNING: Number of suppressed warningings about integral evaluations where target precision was not reached is 132

# %%
#Plotting fit results:
#We create a plot from the first random variable
frame = mass.frame(ROOT.RooFit.Title("mass distribution"))
BinnedEvents.plotOn(frame)

prod_sum_pdf.plotOn(frame)
bkg_arg = ROOT.RooArgSet(BkgShape)
sig_arg = ROOT.RooArgSet(SignalHistoShape)

prod_sum_pdf.plotOn(frame,ROOT.RooFit.Components(bkg_arg), ROOT.RooFit.LineStyle(ROOT.kDotted) ) 
prod_sum_pdf.plotOn(frame,ROOT.RooFit.Components(sig_arg), ROOT.RooFit.LineStyle(ROOT.kDashed),ROOT.RooFit.LineColor(ROOT.kRed) ) 

c1 = ROOT.TCanvas("c1","Mass fit")
frame.Draw()
#We create a plot from the second random variable
framenev = nev.frame(ROOT.RooFit.Title("number of events distribution"))

c1.Draw()
c1.SaveAs("exampleFit.png")
# Out:
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extPDF) directly selected PDF components: (expo)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extPDF) indirectly selected PDF components: (sumPDF)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extPDF) directly selected PDF components: (sighisto)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extPDF) indirectly selected PDF components: (sumPDF)
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: png file exampleFit.png has been created

# %%
#Now let's save the different components of the fit:
w = ROOT.RooWorkspace("ws")
getattr(w,'import')(total_events)
getattr(w,'import')(prod_sum_pdf)
fout = ROOT.TFile("WorkspaceFile.root","RECREATE")#Open per non modificarlo, new per crearlo da zero se non c'è,Update per modificarlo senza sovrascriverlo
w.Write()
fout.Close()
# Out:
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing dataset extPDFData
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooRealVar::mass
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing dataset dh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooProdPdf::extPDF
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooAddPdf::sumPDF
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooHistPdf::sighisto
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooRealVar::signal
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooExponential::expo
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooRealVar::lam
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooRealVar::background
# [#1] INFO:Caching -- RooExpensiveObjectCache::importCache() importing cache object pois_Int[background,signal] associated with object pois
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooPoisson::pois
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooRealVar::n
# [#1] INFO:ObjectHandling -- RooWorkspace::import(ws) importing RooFormulaVar::total_events

# %%
print("Doing part 2: fit sanity checks")
#Part 2.1: let's extract the workspace!
fin = ROOT.TFile("WorkspaceFile.root")
ws = fin.Get("ws")#NOTE: Root saves files with the "Name" field!!!
ws.Print()
#  return
# Out:
# Doing part 2: fit sanity checks
#
# RooWorkspace(ws) ws contents
#
# variables
# ---------
# (background,lam,mass,n,signal)
#
# p.d.f.s
# -------
# RooExponential::expo[ x=mass c=lam ] = 0.986072
# RooProdPdf::extPDF[ sumPDF * pois ] = 0.00887976
# RooPoisson::pois[ x=n mean=total_events ] = 0.0112864
# RooHistPdf::sighisto[ pdfObs=(mass) ] = 0
# RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.786764
#
# functions
# --------
# RooFormulaVar::total_events[ actualVars=(signal,background) formula="x[0]+x[1]" ] = 1248.5
#
# datasets
# --------
# RooDataSet::extPDFData(mass)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::dh(mass)
#
# embedded precalculated expensive components
# -------------------------------------------
# uid = 0 key=pois_Int[background,signal] value=RooDouble::1264.000000 parameters=( n=1263.12 )

# %%
print(ws.pdf("sumPDF"))
print(ws.pdf("gauss"))
print(ws.pdf("expo"))
print(ws.var("signal"))
# Out:
# RooAddPdf::sumPDF[ signal * sighisto + background * expo ] = 0.786764
#
# <cppyy.gbl.RooAbsPdf object at 0x(nil)>
# RooExponential::expo[ x=mass c=lam ] = 0.986072
#
# RooRealVar::signal = 252.35 +/- 24.3161  L(0 - 2000)

# %%
#Now let's make the pseudoexperiments:
mc_study = ROOT.RooMCStudy(ws.pdf("sumPDF"), ROOT.RooArgSet(ws.var("mass")),ROOT.RooFit.Silence(),ROOT.RooFit.FitOptions(ROOT.RooFit.PrintLevel(0)),
                           ROOT.RooFit.Extended(1), ROOT.RooFit.FitOptions(ROOT.RooFit.Save(1)),
                          Verbose=False)
mc_study.generateAndFit(200,)#performs both generation and fit
# Out:
# False
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1250 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 198
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1299 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1269 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 196
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1300 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1285 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 194
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1280 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1209 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 192
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1245 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1330 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 190
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1191 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1281 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 188
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1273 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1254 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 186
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1180 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1206 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 184
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1210 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1246 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 182
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1189 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1277 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 180
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1192 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1255 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 178
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1215 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1220 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 176
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1294 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1229 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 174
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1320 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1258 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 172
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1234 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1263 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 170
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1258 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1289 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 168
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1312 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1225 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 166
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1253 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1188 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 164
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1276 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1247 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 162
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1245 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1240 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 160
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1190 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1205 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 158
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1222 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1233 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 156
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1286 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1233 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 154
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1263 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1230 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 152
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1238 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1243 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 150
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1272 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1254 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 148
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1275 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1246 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 146
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1254 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1210 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 144
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1212 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1210 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 142
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1294 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1297 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 140
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1247 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1224 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 138
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1234 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1301 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 136
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1283 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1242 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 134
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1254 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1196 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 132
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1286 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1280 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 130
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1233 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1294 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 128
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1270 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1225 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 126
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1310 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1312 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 124
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1273 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1281 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 122
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1222 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1198 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 120
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1243 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1200 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 118
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1209 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1215 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 116
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1227 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1226 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 114
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1237 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1219 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 112
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1294 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1265 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 110
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1265 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1258 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 108
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1247 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1243 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 106
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1319 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1209 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 104
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1190 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1260 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 102
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1272 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1312 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 100
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1229 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1285 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 98
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1260 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1216 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 96
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1251 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1188 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 94
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1277 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1226 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 92
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1256 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1223 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 90
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1282 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1200 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 88
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1227 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1337 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 86
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1207 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1262 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 84
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1197 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1258 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 82
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1229 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1210 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 80
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1170 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1263 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 78
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1192 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1268 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 76
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1282 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1186 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 74
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1277 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1257 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 72
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1237 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1292 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 70
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1206 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1194 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 68
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1340 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1281 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 66
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1222 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1240 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 64
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1166 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1273 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 62
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1287 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1213 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 60
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1225 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1303 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 58
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1278 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1249 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 56
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1247 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1275 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 54
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1228 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1194 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 52
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1185 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1247 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 50
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1213 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1305 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 48
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1283 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1326 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 46
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1219 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1271 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 44
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1304 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1279 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 42
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1193 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1230 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 40
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1236 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1265 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 38
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1232 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1274 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 36
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1232 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1263 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 34
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1276 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1268 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 32
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1300 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1217 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 30
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1302 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1198 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 28
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1256 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1156 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 26
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1271 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1252 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 24
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1208 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1248 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 22
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1255 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1236 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 20
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1087 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1187 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 18
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1231 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1257 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 16
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1278 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1224 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 14
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1276 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1300 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 12
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1238 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1222 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 10
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1279 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1229 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 8
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1248 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1220 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 6
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1232 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1304 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 4
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1213 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1223 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 2
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1229 events
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1271 events
# [#0] PROGRESS:Generation -- RooMCStudy::run: sample 0
# [#0] PROGRESS:Generation -- RooMCStudy: now generating 1249 events

# %%
frame_nll = mc_study.plotNLL(ROOT.RooFit.Bins(40))
frame_sig = mc_study.plotParam(ws.var("signal"),ROOT.RooFit.Bins(40))
frame_err = mc_study.plotError(ws.var("signal"),ROOT.RooFit.Bins(40))
frame_pulls = mc_study.plotPull(ws.var("signal"),ROOT.RooFit.Bins(40),ROOT.RooFit.FitGauss(1))
# Out:
# [#0] WARNING:Plotting -- Cannot apply a bin width correction and use Poisson errors. Not correcting for bin width.
# [#0] WARNING:Plotting -- Cannot apply a bin width correction and use Poisson errors. Not correcting for bin width.
# [#0] WARNING:Plotting -- Cannot apply a bin width correction and use Poisson errors. Not correcting for bin width.
# [#0] WARNING:Plotting -- Cannot apply a bin width correction and use Poisson errors. Not correcting for bin width.
#
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(pullGauss_Int[signalpull]) using numeric integrator RooIntegrator1D to calculate Int(signalpull)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(pullGauss_Int[signalpull]) using numeric integrator RooIntegrator1D to calculate Int(signalpull)

# %%
# %jsroot on
c1=ROOT.TCanvas("stattests","Statistical Tests",50,50,1000,1000)

c1.Divide(2,2)
c1.cd(1)
frame_nll.Draw()
c1.cd(2)
frame_sig.Draw()
c1.cd(3)
frame_err.Draw()
c1.cd(4)
frame_pulls.Draw()

c1.Draw()
c1.SaveAs("StatisticalTests.png")
# Out:
# Info in <TCanvas::Print>: png file StatisticalTests.png has been created
# <div id="root_plot_1654807803985"
#      style="width: 996px; height: 972px">
# </div>
# <script>
#
# function display_root_plot_1654807803985(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":996,"fYtoAbsPixelk":972.00005,"fYtoPixelk":972.00005,"fYtoPixel":-972,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":996,"fVtoAbsPixelk":972.00005,"fVtoPixelk":972,"fVtoPixel":-972,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00100401606425703,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00102880658436214,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-706.012420254374,"fY1":-3.78856233607916,"fX2":-42.1566429954483,"fY2":34.0970587665533,"fXtoAbsPixelk":518.399427353077,"fXtoPixelk":508.4394275757,"fXtoPixel":0.720156420750376,"fYtoAbsPixelk":429.624047392893,"fYtoPixelk":419.904047610152,"fYtoPixel":-12.3149624278457,"fUtoAbsPixelk":9.96004977737665,"fUtoPixelk":5e-5,"fUtoPixel":478.080000445247,"fVtoAbsPixelk":476.280050217259,"fVtoPixelk":466.560000434518,"fVtoPixel":-466.560000434518,"fAbsPixeltoXk":-719.842748625256,"fPixeltoXk":-706.012420254374,"fPixeltoX":1.38858721686885,"fAbsPixeltoYk":34.8863425211479,"fPixeltoYk":-3.78856233607916,"fPixeltoY":-0.0812020341807029,"fXlowNDC":0.00999999977648258,"fYlowNDC":0.509999999776483,"fXUpNDC":0.490000000223517,"fYUpNDC":0.990000000223517,"fWNDC":0.480000000447035,"fHNDC":0.480000000447035,"fAbsXlowNDC":0.00999999977648258,"fAbsYlowNDC":0.509999999776483,"fAbsWNDC":0.480000000447035,"fAbsHNDC":0.480000000447035,"fUxmin":-639.626838571592,"fUymin":0,"fUxmax":-108.54222467823,"fUymax":30.3084964304742,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":1,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-639.626838571592,"fY1":0,"fX2":-108.54222467823,"fY2":30.3084964304742,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":520,"fName":"frame_56257e423990","fTitle":"A RooPlot of \"-log(Likelihood)\"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":42,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"-log(Likelihood)","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":40,"fXmin":-639.626838571592,"fXmax":-108.54222467823 ...
